# %% [markdown]
# ### РОССИЙСКИЙ УНИВЕРСИТЕТ ДРУЖБЫ НАРОДОВ
#
# #### Факультет физико-математических и естественных наук
# #### Кафедра математического моделирования и искусственного интеллекта

# %% [markdown]
# ## ОТЧЕТ ПО КОНТРОЛЬНОЙ РАБОТЕ № 1
#
#
# ### Дисциплина: Методы машинного обучения

# %% [markdown]
# ##### Студент:  Абу Сувейлим Мухаммед Мунифович
# ##### Группа:   НКНбд-01-21

# %% [markdown]
# ## Москва 2024
# ***

# %% [markdown]
# ### Вариант №1
#
# 1. Набор данных: cherry_blossoms
#
# 2. Независимая переменная: temp
#
# 3. Зависимая переменная: temp_lower
#
# 4. Визуализация для независимой переменной – столбчатая диаграмма
#
# 5. Визуализация для зависимой переменной – эмпирическая плотность распределения
#
# 6. Показатель качества регрессии – MAE (mean absolute error)

# %%
# Download all the libraries and packages needed
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from tensorflow.keras.layers import Input, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# loading cherry_blossoms dataset
ds = tfds.load("cherry_blossoms", split='train')
ds
# Convert tf.data.cherry_blossoms to a panda dataframe
df = tfds.as_dataframe(ds)
df.head()
# list of the dataframe shape, size and other info
df.info()
# Dataset analysis
df.describe()
# Drop all not needed feauters
df = df.drop(columns=['doy', 'temp_upper', 'year'])
df.head()
# CaLculating Correlation
df.corr()
# Correlation between all pairs
# Pair of least correlation (-0.499087) - is the pair year-temp_upper 
# Pair of highest correlation (0.767866) - is the pair temp-temp_upper 
corrDF = tfds.as_dataframe(ds)
corrDF.corr()
# Bar chart for independant variable temp
subset_df = df[::14]  # Select every 14th row (2 weeks)
plt.figure(figsize=(24, 6))  # Set the figure size (width=12, height=6)

# Create a bar plot of the 'temp' column from subset_df
subset_df['temp'].plot.bar(title='temp Bar chart every two weeks')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)  # Rotate labels by 45 degrees
plt.show()
# Empirical distribution function for dependant variable temp_lower
df['temp_lower'].plot.hist(color='yellow', edgecolor='black', bins=30, density=True);
# Feature Scatterplot for temp and temp_lower
df.plot.scatter('temp','temp_lower',title='Feature Scatterplot temp и temp_lower');
# We can see that we have a few outlier points that we need to remove
df['temp_lower'].plot.box(title='temp_lower range');
# we make temp and temp-lower columns into numpy arrays
x = df['temp'].values
y = df['temp_lower'].values
x.shape, y.shape
# condiations
conditionOne = (y > 3)
conditionTwo = (y < 7)
x = x[conditionOne & conditionTwo]
y = y[conditionOne & conditionTwo]
x.shape, y.shape
plt.scatter(x, y, color='blue')
plt.xlabel('temp')  # Customize x-axis label
plt.ylabel('temp_lower')  # Customize y-axis label
plt.title('Scatter Plot') 
# load scikit-learn to then split the dataset
# !pip install scikit-learn
# Lets build a simple linear regression model that uses an analytical method to predicte y values
from sklearn.model_selection import train_test_split
# Split the cleaned dataset into 20% testing and 80% training  and randomize it a it
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
class SimpleLinReg:

    def __init__(self):
        self.a_ = None
        self.b_ = None

    def fit(self, x_train, y_train):
        assert x_train.ndim == 1, \
            "В данных должен быть один признак"
        assert len(x_train) == len(y_train), \
            "Данные должны иметь одинаковый размер"

        x_mean = np.mean(x_train)
        y_mean = np.mean(y_train)

        self.a_ = (x_train - x_mean).dot(y_train - y_mean) / \
                  (x_train - x_mean).dot(x_train - x_mean)
        self.b_ = y_mean - self.a_ * x_mean

        return self

    def predict(self, x_predict):
        assert x_predict.ndim == 1, \
            "В данных должен быть один признак"
        assert self.a_ is not None and self.b_ is not None, \
            "Модель вначале должна быть обучена"

        return np.array([self._predict(x) for x in x_predict])

    def _predict(self, x_single):
        return self.a_ * x_single + self.b_

    def __repr__(self):
        return "SimpleLinearReg()"
reg = SimpleLinReg()
reg.fit(x, y)
# find coff a and b in y = ax+b
reg.a_, reg.b_
plt.scatter(x, y, label='Data points')
plt.plot(x, reg.predict(x), color='r', label='excat line of regression')
plt.xlabel('temp')  # Customize x-axis label
plt.ylabel(' temp_lower')  # Customize y-axis label
plt.title('Scatter Plot')
plt.legend()
plt.legend(loc='upper left')
plt.scatter(x, y, color='g', label='train data points')
plt.scatter(x_test, y_test, color='c',label='test data points')
plt.plot(x, reg.predict(x), color='r');
plt.xlabel('temp')  # Customize x-axis label
plt.ylabel(' temp_lower')  # Customize y-axis label
plt.title('Scatter Plot')
plt.legend()
plt.legend(loc='upper left')
# Let's calcuclate prediction values for the test set points to assess the quality of the regression model
y_predict = reg.predict(x_test)
y_predict
# Mean Absolute Error, MAE
mae_test = np.sum(np.absolute(y_predict - y_test))/len(y_test)
mae_test
# Mean Squared Error, MSE
mse_test = np.sum((y_predict - y_test)**2) / len(y_test)
mse_test
# Coefficient of determination measures the proportion of variance explained by the model in the total variance of the target variable.
1 - mse_test/np.var(y_test)
# The model is only able to explain approximately 46.26% of the variance in the test data which is bad.
print(tf.__version__)
# Let's build a simple linear regression model that uses a simple neural network with one layer that has one neutron
# We use keras API sequential model which means a sequence of layers, where the output of each layer becomes the input to the next layer.
# A dense layer is a fully connected layer meaning each neuron is connected to every neuron in the previous layer

# Input shape (1,) for a single input feature
input_shape = (1,)

# Create thru Keras' API a Sequential model
model = tf.keras.Sequential()

# Add the Input layer specifying the input shape
model.add(tf.keras.Input(shape=input_shape))

# Add a Dense layer with 1 neuron (output) to perform linear regression
model.add(tf.keras.layers.Dense(1))

# Print the model summary
model.summary()

# The two parameters are Weight and Bias
# Let's set up the process of its training by calling the compile() method:
model.compile(
    loss=tf.keras.losses.mean_absolute_error,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.25),
    metrics=['mean_absolute_error']
)
# Here, the mean absolute error MAE is used as a loss function (error) and to assess the quality of the model.
# The model can be trained on the training data using the fit() method:
model.fit(x, y, epochs=100) # verbose=0
# At the beginning the loss was 0.5363 and by the end it got slightly better (i.e. lower) 0.4062
# Let's predict the values of the dependent variable (response) and display the first 10 predictions 
y_predict2 = model.predict(x_test)
y_predict2[:10]
plt.figure(figsize=(12,8))
plt.scatter(x, y, color='g', label='train data points')
plt.scatter(x_test, y_test, color='c',label='test data points')
plt.plot(x_test, y_predict, c='r', label='exact regression line')
plt.plot(x_test, y_predict2, c='m', label='regression line (ANN)')
plt.legend();
# The results are quite similar and one could aruge the neural network was overfitted and is actully worse. 
# The  exact regression line model had a MAE of 0.3812
# The neural network at its last epoch of training had a MAE of 0.4062 which is higher than that of the exact regression line model
# You can see however that there weight in the neural network model where the MAE is equal to 0.3600 (epoch 75)
# Let's now normlaize the data and rebuild the model
normalizer = tf.keras.layers.Normalization()
# Paired regression
feature = np.array(x_train)

feature_normalizer = tf.keras.layers.Normalization(axis=None,input_shape=(1,))
feature_normalizer.adapt(feature)
# Let's build a sequential model with two layers:

feature_model = tf.keras.Sequential([
    feature_normalizer,
    tf.keras.layers.Dense(units=1)
])
feature_model.summary()
# For testing, let's run the untrained model on the first few values to check the result:
print(feature[:10])
feature_model.predict(feature[:10])
# After building the model, we will set up the training procedure using the compile() method. 
# The most important compilation arguments are the loss function and the optimizer, 
# since they determine what will be optimized (mean_absolute_error) and how (Adam optimizer).


feature_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.25),
    loss='mean_absolute_error')
import time
# After setting up the training, we'll use the `fit()` method to perform the training:
start_time = time.time()
history = feature_model.fit(
    x_train, y_train,
    epochs=100,
    # suppress output
    verbose=0,
    # check (validation) on 20% of training data
    validation_split = 0.2)
end_time = time.time()
execution_time = end_time - start_time
print(f"Execution Time: {execution_time} seconds")
# Let's visualize the model's training progress using statistics stored in the `history` object.

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, max(history.history['loss'])*0.5])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
plot_loss(history)
test_results = {} # пустой словарь

test_results['feature_model'] = feature_model.evaluate(
    x_train,
    y_train, verbose=0)
x = tf.linspace(4., 9., 51)
y = feature_model.predict(x)
def plot_rm(x, y):
  plt.scatter(x_train, y_train, label='Data')
  plt.plot(x, y, color='k', label='Prediction')
  plt.xlabel('temp')
  plt.ylabel('temp_lower')
  plt.legend()
plot_rm(x,y)
X = df.drop('temp_lower', axis=1)
Y = df['temp_lower']
mean_y = df['temp_lower'].mean()
std_y = df['temp_lower'].std()
Y = (df['temp_lower'] - mean_y) / std_y
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train.shape
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
mean = np.mean(x_train, axis=0)
std = np.std(x_train, axis=0)
x_train_normalized = (x_train - mean) / std
x_test_normalized = (x_test - mean) / std
# Create a Sequential model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(x_train.shape[1],))  # Specify input_shape based on number of features
])
linear_model.compile(
optimizer=tf.optimizers.Adam(learning_rate=0.25),
loss='mean_absolute_error')
history = linear_model.fit(
x_train, y_train,
epochs=100,
verbose=0,
validation_split = 0.2)
# Create a Sequential model with a Dense layer and L1 regularization
l1_model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, kernel_regularizer=tf.keras.regularizers.L1(l1=0.0))
])

# Compile the model with Adam optimizer and mean absolute error loss
l1_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.25),
    loss='mean_absolute_error'
)

# Train the model
history1 = l1_model.fit(
    x_train, y_train,
    epochs=100,
    verbose=0,
    validation_split=0.2
)

# Create a Sequential model with a Dense layer and L2 regularization
l2_model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, kernel_regularizer=tf.keras.regularizers.L2(l2=0.0))
])

# Compile the model with Adam optimizer and mean absolute error loss
l2_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.25),
    loss='mean_absolute_error'
)

# Train the model
history2 = l2_model.fit(
    x_train, y_train,
    epochs=100,
    verbose=0,
    validation_split=0.2
)
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Drop rows with NaN values from x_test
x_test = x_test.dropna(axis=0)
y_test = y_test.dropna(axis=0)
x_test
y_test
# Out:
# <class 'tensorflow_datasets.core.as_dataframe.as_dataframe.<locals>.StyledDataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   doy         827 non-null    float32
#  1   temp        1124 non-null   float32
#  2   temp_lower  1124 non-null   float32
#  3   temp_upper  1124 non-null   float32
#  4   year        1215 non-null   int32
# dtypes: float32(4), int32(1)
# memory usage: 23.9 KB
# Requirement already satisfied: scikit-learn in c:\users\mo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\mo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\mo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.4.0)
# 2.16.1
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 4.8136 - mean_absolute_error: 4.8136
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.4715 - mean_absolute_error: 0.4715
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.4144 - mean_absolute_error: 0.4144
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.4543 - mean_absolute_error: 0.4543
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.3870 - mean_absolute_error: 0.3870
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.3961 - mean_absolute_error: 0.3961
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.3954 - mean_absolute_error: 0.3954
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 0.3552 - mean_absolute_error: 0.3552
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.4074 - mean_absolute_error: 0.4074
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.3949 - mean_absolute_error: 0.3949
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.3960 - mean_absolute_error: 0.3960
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.3856 - mean_absolute_error: 0.3856
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.3902 - mean_absolute_error: 0.3902
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.3689 - mean_absolute_error: 0.3689
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.4188 - mean_absolute_error: 0.4188
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 250us/step - loss: 0.4345 - mean_absolute_error: 0.4345
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.3962 - mean_absolute_error: 0.3962
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - loss: 0.3845 - mean_absolute_error: 0.3845
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.3703 - mean_absolute_error: 0.3703
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.3950 - mean_absolute_error: 0.3950
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.3934 - mean_absolute_error: 0.3934
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.3948 - mean_absolute_error: 0.3948
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 0.4120 - mean_absolute_error: 0.4120
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.3766 - mean_absolute_error: 0.3766
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.3558 - mean_absolute_error: 0.3558
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.3554 - mean_absolute_error: 0.3554
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.3729 - mean_absolute_error: 0.3729
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 73us/step - loss: 0.4040 - mean_absolute_error: 0.4040
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.4078 - mean_absolute_error: 0.4078
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.4126 - mean_absolute_error: 0.4126
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.4224 - mean_absolute_error: 0.4224
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.3454 - mean_absolute_error: 0.3454
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.3568 - mean_absolute_error: 0.3568
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.4146 - mean_absolute_error: 0.4146
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.4035 - mean_absolute_error: 0.4035
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.3766 - mean_absolute_error: 0.3766
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.3671 - mean_absolute_error: 0.3671
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.3863 - mean_absolute_error: 0.3863
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - loss: 0.3615 - mean_absolute_error: 0.3615
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 59us/step - loss: 0.3547 - mean_absolute_error: 0.3547
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.3828 - mean_absolute_error: 0.3828
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - loss: 0.3658 - mean_absolute_error: 0.3658
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.3816 - mean_absolute_error: 0.3816
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.3806 - mean_absolute_error: 0.3806
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.3968 - mean_absolute_error: 0.3968
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - loss: 0.3832 - mean_absolute_error: 0.3832
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 81us/step - loss: 0.4496 - mean_absolute_error: 0.4496
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.3443 - mean_absolute_error: 0.3443
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 0.4829 - mean_absolute_error: 0.4829
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - loss: 0.4475 - mean_absolute_error: 0.4475
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.3517 - mean_absolute_error: 0.3517
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - loss: 0.3847 - mean_absolute_error: 0.3847
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.3623 - mean_absolute_error: 0.3623
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.3943 - mean_absolute_error: 0.3943
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3621 - mean_absolute_error: 0.3621
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3772 - mean_absolute_error: 0.3772
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 0.3916 - mean_absolute_error: 0.3916
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.3744 - mean_absolute_error: 0.3744
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 0.3849 - mean_absolute_error: 0.3849
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.3971 - mean_absolute_error: 0.3971
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 225us/step - loss: 0.3694 - mean_absolute_error: 0.3694
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 0.3832 - mean_absolute_error: 0.3832
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.4467 - mean_absolute_error: 0.4467
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.4315 - mean_absolute_error: 0.4315
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.4212 - mean_absolute_error: 0.4212
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 159us/step - loss: 0.4091 - mean_absolute_error: 0.4091
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.3896 - mean_absolute_error: 0.3896
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.4251 - mean_absolute_error: 0.4251
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.4085 - mean_absolute_error: 0.4085
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.4480 - mean_absolute_error: 0.4480
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - loss: 0.3622 - mean_absolute_error: 0.3622
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.3793 - mean_absolute_error: 0.3793
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 0.3651 - mean_absolute_error: 0.3651
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.3724 - mean_absolute_error: 0.3724
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.3805 - mean_absolute_error: 0.3805
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.4171 - mean_absolute_error: 0.4171
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.3776 - mean_absolute_error: 0.3776
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.3636 - mean_absolute_error: 0.3636
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.3785 - mean_absolute_error: 0.3785
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.3781 - mean_absolute_error: 0.3781
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 189us/step - loss: 0.3683 - mean_absolute_error: 0.3683
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.3845 - mean_absolute_error: 0.3845
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.3800 - mean_absolute_error: 0.3800
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.3684 - mean_absolute_error: 0.3684
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.3939 - mean_absolute_error: 0.3939
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.3916 - mean_absolute_error: 0.3916
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 0.3665 - mean_absolute_error: 0.3665
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 0.3545 - mean_absolute_error: 0.3545
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 0.4045 - mean_absolute_error: 0.4045
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.3597 - mean_absolute_error: 0.3597
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.3689 - mean_absolute_error: 0.3689
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 0.4479 - mean_absolute_error: 0.4479
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.3821 - mean_absolute_error: 0.3821
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.3787 - mean_absolute_error: 0.3787
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.3710 - mean_absolute_error: 0.3710
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.3910 - mean_absolute_error: 0.3910
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.3809 - mean_absolute_error: 0.3809
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.4128 - mean_absolute_error: 0.4128
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.3827 - mean_absolute_error: 0.3827
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 0.3716 - mean_absolute_error: 0.3716
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# C:\Users\Mo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\preprocessing\normalization.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_7 (Normalization)      │ (None, 1)                   │               3 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5 (24.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 3 (16.00 B)
# [5.48 5.41 7.4  5.87 6.29 6.   6.49 5.34 6.07 6.31]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Execution Time: 3.6105284690856934 seconds
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\Mo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 260
#     256 # Create a Sequential model
#     257 model = tf.keras.Sequential([
#     258     tf.keras.layers.Dense(units=1, input_shape=(x_train.shape[1],))  # Specify input_shape based on number of features
#     259 ])
# --> 260 linear_model.compile(
#     261 optimizer=tf.optimizers.Adam(learning_rate=0.25),
#     262 loss='mean_absolute_error')
#     263 history = linear_model.fit(
#     264 x_train, y_train,
#     265 epochs=100,
#     266 verbose=0,
#     267 validation_split = 0.2)
#     268 # Create a Sequential model with a Dense layer and L1 regularization
#
# NameError: name 'linear_model' is not defined

# %%
mse_linear = mean_squared_error(y_test, linear_model.predict(x_test))
mse_l1 = mean_squared_error(y_test, l1_model.predict(x_test))
mse_l2 = mean_squared_error(y_test, l2_model.predict(x_test))
print("\nMSE:")
print("Linear Model:", mse_linear)
print("L1 Model:", mse_l1)
print("L2 Model:", mse_l2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mse_linear = mean_squared_error(y_test, linear_model.predict(x_test))
#       2 mse_l1 = mean_squared_error(y_test, l1_model.predict(x_test))
#       3 mse_l2 = mean_squared_error(y_test, l2_model.predict(x_test))
#
# NameError: name 'linear_model' is not defined
